# %%
from opensimrl.train import train
import matplotlib.pyplot as plt

# %%
rewards = train()
# Out:
# Episode 0, Average Reward: -1.00
# Episode 100, Average Reward: -0.08
# Episode 200, Average Reward: 0.85
# Episode 300, Average Reward: 0.89
# Episode 400, Average Reward: 0.90
# Episode 500, Average Reward: 0.91
# Episode 600, Average Reward: 0.91
# Episode 700, Average Reward: 0.92
# Episode 800, Average Reward: 0.91
# Episode 900, Average Reward: 0.92

# %%
plt.plot(rewards)
plt.title('PPO Training on GridWorld')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.show()
