# %%
from opensimrl.train_ppo import train_ppo_cartpole
import matplotlib.pyplot as plt

# %%
rewards = train_ppo_cartpole()
# Out:
# ...
# Epoch 0 | EpRetMean 15.700 | EpLenMean 15.7 | LossPi 0.0000 | LossV 226.5497 | KL 0.00938 | CF 0.141 | Ent 0.6888 | Interacts 4000 | Time 0.62s
# ...
# Epoch 1 | EpRetMean 17.700 | EpLenMean 17.7 | LossPi 0.0000 | LossV 208.6345 | KL 0.00679 | CF 0.075 | Ent 0.6883 | Interacts 8000 | Time 1.22s
# ...
# Epoch 2 | EpRetMean 34.500 | EpLenMean 34.5 | LossPi -0.0000 | LossV 264.8900 | KL 0.00515 | CF 0.069 | Ent 0.6750 | Interacts 12000 | Time 1.82s
# ...
# Epoch 3 | EpRetMean 53.600 | EpLenMean 53.6 | LossPi -0.0000 | LossV 429.8571 | KL 0.00578 | CF 0.069 | Ent 0.6575 | Interacts 16000 | Time 2.43s
# ...
# Epoch 4 | EpRetMean 97.900 | EpLenMean 97.9 | LossPi 0.0000 | LossV 709.8696 | KL 0.00500 | CF 0.040 | Ent 0.6363 | Interacts 20000 | Time 3.03s
# ...
# Epoch 5 | EpRetMean 92.100 | EpLenMean 92.1 | LossPi 0.0000 | LossV 753.5724 | KL 0.00543 | CF 0.050 | Ent 0.6241 | Interacts 24000 | Time 3.63s
# ...

# %%
plt.plot(rewards)
plt.title('PPO Training on CartPole')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.savefig('cartpole_training_results.png')
plt.show()
