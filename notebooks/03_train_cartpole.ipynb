# %%
from opensimrl.train_cartpole import train_cartpole
import matplotlib.pyplot as plt

# %%
rewards = train_cartpole()
# Out:
# /Users/aribrin/Projects/opensimrl/opensimrl/algorithms/ppo.py:27: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:256.)
#   observations = torch.FloatTensor(observations)
# Episode 0, Average Reward: 28.00
# Episode 100, Average Reward: 22.02
# Episode 200, Average Reward: 18.08
# Episode 300, Average Reward: 18.43
# Episode 400, Average Reward: 19.63
# Episode 500, Average Reward: 18.07
# Episode 600, Average Reward: 17.44
# Episode 700, Average Reward: 19.78
# Episode 800, Average Reward: 18.65
# Episode 900, Average Reward: 20.26

# %%
plt.plot(rewards)
plt.title('PPO Training on CartPole')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.savefig('cartpole_training_results.png')
plt.show()
