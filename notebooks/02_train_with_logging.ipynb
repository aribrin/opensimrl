# %%
from opensimrl.train_with_logging import train

# %%
rewards = train()
# Out:
# wandb: Currently logged in as: ari-brin (adapt-solutions) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# Tracking run with wandb version 0.21.4
# Run data is saved locally in <code>/Users/aribrin/Projects/opensimrl/notebooks/wandb/run-20250919_120501-13onh7xq</code>
# Syncing run <strong><a href='https://wandb.ai/adapt-solutions/opensimrl/runs/13onh7xq' target="_blank">ppo_gridworld_v1</a></strong> to <a href='https://wandb.ai/adapt-solutions/opensimrl' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/adapt-solutions/opensimrl' target="_blank">https://wandb.ai/adapt-solutions/opensimrl</a>
# ...
