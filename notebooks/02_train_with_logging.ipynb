# %%
from opensimrl.train_with_logging import train
import matplotlib.pyplot as plt

# %%
rewards = train()
# Out:
# Tracking run with wandb version 0.21.4
# Run data is saved locally in <code>/Users/aribrin/Projects/opensimrl/notebooks/wandb/run-20250918_180844-u107iuh2</code>
# Syncing run <strong><a href='https://wandb.ai/adapt-solutions/opensimrl/runs/u107iuh2' target="_blank">ppo_gridworld_v1</a></strong> to <a href='https://wandb.ai/adapt-solutions/opensimrl' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/adapt-solutions/opensimrl' target="_blank">https://wandb.ai/adapt-solutions/opensimrl</a>
#  View run at <a href='https://wandb.ai/adapt-solutions/opensimrl/runs/u107iuh2' target="_blank">https://wandb.ai/adapt-solutions/opensimrl/runs/u107iuh2</a>
# Step 0: episode_reward: -1.0000, average_reward: -1.0000, average_policy_loss: 0.0958, average_value_loss: 0.0147, episode_length: 100.0000
# ...
